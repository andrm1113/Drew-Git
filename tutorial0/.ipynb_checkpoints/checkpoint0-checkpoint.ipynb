# %% [markdown]
# # Checkpoint 0

# %% [markdown]
# These exercises are a mix of Python and Pandas practice. Most should be no more than a few lines of code!

# %%
# here is a Python list:

a = [1, 2, 3, 4, 5, 6]

# %%
# get a list containing the last 3 elements of a
# Yes, you can just type out [4, 5, 6] but we really want to see you demonstrate you know how to do that in Python

a_last_three = a[-3:]
# Out:
# [4, 5, 6]

# %%
# create a list of numbers from 1 to 100

one_to_hundred = list(range(1,101))

# %%
# now get a list with only the even numbers between 1 and 100
# you may or may not make use of the list you made in the last cell

one_to_hundred_even = list(range(2,101,2))

# %%
# write a function that takes two numbers as arguments
# and returns the first number divided by the second

def arg1_over_arg2(arg1, arg2):
    answer = arg1 / arg2
    return answer
# Out:
# 2.0

# %%
# write a function that takes a string as input
# and return that string in all caps

def all_caps(lower_string):
    capitalized = lower_string.upper()
    return capitalized

# %%
# optional challenge - fizzbuzz
# you will need to use both iteration and control flow 
# go through all numbers from 1 to 100 in order
# if the number is a multiple of 3, print fizz
# if the number is a multiple of 5, print buzz
# if the number is a multiple of 3 and 5, print fizzbuzz and NOTHING ELSE
# if the number is neither a multiple of 3 nor a multiple of 5, print the number

nums = list(range(1,101))
for num in nums:
    if num % 3 == 0 and num % 5 == 0:
        print('fizzbuzz')
    elif num % 3 == 0:
        print('fizz')
    elif num % 5 == 0:
        print('buzz')
    else:
        print(num)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %%
# create a dictionary that reflects the following menu pricing (taken from Ahmo's)
# Gyro: $9 
# Burger: $9
# Greek Salad: $8
# Philly Steak: $10

ahmos_prices = {'Gyro':9, 'Burger':9, 'Greek Salad':8, 'Philly Steak':10}

# %%
# load in the "starbucks.csv" dataset
# refer to how we read the cereal.csv dataset in the tutorial

import numpy as np
import pandas as pd

starbucks_df = pd.read_csv("../data/starbucks.csv")
starbucks_df.describe()
# Out:
#          calories   total fat   trans fat  saturated fat      sodium  \
# count  242.000000  242.000000  242.000000     242.000000  242.000000
# mean   193.871901    2.904959    1.307025       0.037603    6.363636
# std    102.863303    2.944376    1.640259       0.071377    8.630257
# min      0.000000    0.000000    0.000000       0.000000    0.000000
# 25%    120.000000    0.200000    0.100000       0.000000    0.000000
# 50%    185.000000    2.500000    0.500000       0.000000    5.000000
# 75%    260.000000    4.500000    2.000000       0.100000   10.000000
# max    510.000000   15.000000    9.000000       0.300000   40.000000
#
#        total carbohydrates  cholesterol  dietary fibre      sugars  \
# count           242.000000   242.000000     242.000000  242.000000
# mean            128.884298    35.991736       0.805785   32.962810
# std              82.303223    20.795186       1.445944   19.730199
# min               0.000000     0.000000       0.000000    0.000000
# ...

# %%
# output the calories, sugars, and protein columns only of every 40th row. 

starbucks_df.loc[::40][["calories", "sugars", "protein"]]
# Out:
#      calories  sugars  protein
# 0           3       0      0.3
# 40          5       0      0.4
# 80        350      58     15.0
# 120       140      20      6.0
# 160       110      24      2.0
# 200       200      41      3.0
# 240       180      35      3.0

# %%
# select all rows with more than and including 400 calories

starbucks_df[starbucks_df["calories"] > 400]
# Out:
#               beverage_category  \
# 83    signature espresso drinks
# 84    signature espresso drinks
# 85    signature espresso drinks
# 128             tazo tea drinks
# 214  frappuccino blended coffee
# 215  frappuccino blended coffee
# 216  frappuccino blended coffee
#
#                                           beverage      beverage_prep  \
# 83   white chocolate mocha (without whipped cream)  Venti Nonfat Milk
# 84   white chocolate mocha (without whipped cream)            2% Milk
# 85   white chocolate mocha (without whipped cream)            Soymilk
# 128                           tazo green tea latte            2% Milk
# 214              java chip (without whipped cream)  Venti Nonfat Milk
# 215              java chip (without whipped cream)         Whole Milk
# 216              java chip (without whipped cream)            Soymilk
#
#      calories  total fat  trans fat  saturated fat  sodium  \
# 83        450        7.0        6.0            0.0      10
# ...

# %%
# select all rows whose vitamin c content is higher than the iron content

starbucks_df[starbucks_df["vitamin c"] > starbucks_df["iron"]]
# Out:
#              beverage_category  \
# 11     classic espresso drinks
# 14     classic espresso drinks
# 35     classic espresso drinks
# 38     classic espresso drinks
# 69   signature espresso drinks
# 72   signature espresso drinks
# 75   signature espresso drinks
# 77   signature espresso drinks
# 78   signature espresso drinks
# 81   signature espresso drinks
# 84   signature espresso drinks
# 118            tazo tea drinks
# 119            tazo tea drinks
# 121            tazo tea drinks
# 122            tazo tea drinks
# 124            tazo tea drinks
# 125            tazo tea drinks
# 127            tazo tea drinks
# 128            tazo tea drinks
# 169      shaken iced beverages
# 170      shaken iced beverages
# 171      shaken iced beverages
# 172                  smoothies
# 175                  smoothies
# 176                  smoothies
# 177                  smoothies
# 178                  smoothies
# 179                  smoothies
# 180                  smoothies
# ...

# %%
# create a new column containing the caffeine per calories of each drink

starbucks_df["caffeine per calories"] = starbucks_df["caffeine"] / (starbucks_df["calories"] + 0.1)
# 0.1 is to avoid division by 0

# %%
# what is the average calorie across all items?

starbucks_df["calories"].mean()
# Out:
# 193.87190082644628

# %%
# how many different categories of beverages are there?

categories = starbucks_df.groupby("beverage_category")
len(categories)
# Out:
# 9

# %%
# what is the average # calories for each beverage category?

categories["calories"].mean()
# Out:
# beverage_category
# classic espresso drinks             140.172414
# coffee                                4.250000
# frappuccino blended coffee          276.944444
# frappuccino blended crme            233.076923
# frappuccino light blended coffee    162.500000
# shaken iced beverages               114.444444
# signature espresso drinks           250.000000
# smoothies                           282.222222
# tazo tea drinks                     177.307692
# Name: calories, dtype: float64

# %%
# plot the distribution of the number of calories in drinks with a histogram

starbucks_df["calories"].plot.hist(edgecolor='black', alpha=0.8, title='Caloric Distribution of Starbucks Drinks')
# Out:
# <AxesSubplot: title={'center': 'Caloric Distribution of Starbucks Drinks'}, ylabel='Frequency'>

# %%
# plot calories against total fat with a scatterplot

starbucks_df.plot.scatter(x="calories", y="total fat", title="Total Fat vs. Calories in Starbucks Drinks", c="red")
# Out:
# <AxesSubplot: title={'center': 'Total Fat vs. Calories in Starbucks Drinks'}, xlabel='calories', ylabel='total fat'>
